# %%
file_list = [
    31062047, 31062152, 31062214, 31062266, 31062311, 31062335, 31062359, 31062367, 31062371, 31062443, 31062520,
    31062584, 31062652, 31062736, 31062846, 31062937, 31063005, 31063081, 31063152, 31063213, 31063281, 31063321,
    31063402, 31063473, 31063534, 31063587, 31063660, 31063726, 31063846, 31063909, 31063996, 31064074, 31064161,
    31064251, 31064332, 31064416, 31064497, 31064584, 31064658, 31064743, 31064824, 31064889, 31064968, 31065040,
    31065109, 31065172, 31065244, 31065324, 31065388, 31065429, 31065445, 31065453, 31065457, 31065462, 31065466,
    31065468, 31065475, 31065495, 31065502, 31065518, 31065528, 31065533, 31065537, 31065545, 31065552, 31065554,
    31065558, 31065599, 31065608, 31065626, 31065641, 31065655, 31065710, 31065751, 31065764, 31065778, 31065791,
    31065811, 31065821, 31065835, 31065836, 31065850, 31065859, 31065860, 31065865, 31065881, 31065886, 31065890,
    31065892, 31065899, 31065907, 31065920, 31065931, 31065942, 31065949, 31065957, 31065970, 31065994, 31066008,
    31066012, 31066020, 31066030, 31066047, 31066054, 31066075, 31066084, 31066095, 31066108, 31066119, 31066120,
    31066128, 31066135, 31066149, 31066162, 31066176, 31066216, 31066224, 31066231, 31066236, 31066249, 31066263,
    31066303, 31066327, 31066344, 31066345, 31066347, 31066348, 31066365, 31066366, 31066371, 31066387, 31074558,
    31074568, 31074583,
]

# %%
# https://www.google.hu/search?q=a&start=0
#  out=s1.html
# https://www.google.hu/search?q=a&start=10
#  out=s2.html
# https://www.google.hu/search?q=a&start=20
#  out=s3.html

# 001xxx.tar

# command
# aria2c --input-file list.txt

# %%
url_format = "https://data.dtu.dk/ndownloader/files/"

# %%
with open("qm9_url.txt", "w") as f:
    for i, num in enumerate(file_list):
        f.write(url_format + str(num) + "\n")
        f.write("  out=" + f"{i:03}" + "xxx.tar\n")
