# %%
import lz4.frame

# %%
import os

# %%
open_file = lz4.frame.open

# %%
path = "/home/holywater2/crystal/dataset_qm9"
file_name = "000001.CHGCAR.lz4"
file = os.path.join(path, file_name)

files = os.listdir("/home/holywater2/crystal/dataset_qm9")
print(len(files))
# Out:
# 133886

# %%
f = open_file(file, "rb")

# %%
for i in range(100):
    print(f.readline())
# Out:
# b'   1.00000000000000     \n'
# b'     5.552546    0.000000    0.000000\n'
# b'     0.000000    5.469782    0.000000\n'
# b'     0.000000    0.000000    5.783041\n'
# b'   C    H \n'
# b'     1     4\n'
# b'Direct\n'
# b'  0.455308  0.565257  0.498811\n'
# b'  0.457982  0.365645  0.497769\n'
# b'  0.639805  0.634355  0.497475\n'
# b'  0.360195  0.631389  0.345839\n'
# b'  0.363257  0.629635  0.654161\n'
# b' \n'
# b'   56   56   56\n'
# b' 0.19764510556E-03 0.26178701609E-03 0.38138385799E-03 0.59095288248E-03 0.90108749466E-03\n'
# b' 0.12667115719E-02 0.16013550322E-02 0.18294869972E-02 0.19393093656E-02 0.20028037494E-02\n'
# b' 0.21417307989E-02 0.24435437308E-02 0.28814192783E-02 0.33161735421E-02 0.35957899464E-02\n'
# b' 0.36690562582E-02 0.36110263765E-02 0.35453952929E-02 0.35403628974E-02 0.35620414974E-02\n'
# b' 0.35129191753E-02 0.33220778192E-02 0.30148173054E-02 0.26938710741E-02 0.24386160593E-02\n'
# ...
